# %%
import pandas as pd
import openpyxl as xl
#import numpy as np

Staff = pd.read_excel('CopyШтат.xlsx')                                                   # считываем файл со штатом сотрудников = Staff
TableForm = pd.read_excel('6.ФормаТабеля.xlsx', '0504421')          #добавляем файл, а именно табель сотрудика //то есть беру второй лист из трех






FullName = (Staff["Фамилия"] + " " + Staff["Имя"] + " " + Staff["Отчество"] + " " + Staff["Табельный номер"] + " " + Staff["Подразделение"].astype("string")) # соединяем ФИО в единное целое //все люди из всех отделов 

FullName = (Staff["Фамилия"] + " " + Staff["Имя"] + " " + Staff["Отчество"] + " " + Staff["Подразделение"].astype("string"))
ColData = Staff['Подразделение'].unique()                                   # все виды УНИКАЛЬНЫХ отделов и т.п. взятые из колонки "V" "Подразделение"  файла 7.Штат.xlsx

for name in ColData:                                                                      # создание xlsx файлов с табелем сотрудника + названием должности из Staff, колонки Подразделение
    TableForm.to_excel(f'{name}.xlsx', index = False , header=False)  # убираем заголовки столбцов и нумерацию строк
    wb = xl.load_workbook(f'{name}.xlsx')                                             #загружаем 
    sheet = wb['Sheet1']                                                                            #присваеваем имя листу в xlsx файле
    sheet['B6'] = name                                                                               #закидываем имя файла = профессия = отдел etc в B6 //ячейка excel 
    wb.save(f'{name}.xlsx')                                                                       #сохраняем

# %%
Staff7.columns.tolist()
# Out:
# ['Номер исполнения',
#  'Фамилия',
#  'Имя',
#  'Отчество',
#  'Табельный номер',
#  'Вид должностного исполнения',
#  'Типовая должность',
#  'Должность',
#  'Типовое подразделение',
#  'Штатная должность',
#  'Тип приказа',
#  'Номер приказа',
#  'Дата приказа',
#  'Дата начала',
#  'Дата окончания',
#  'Категория сотрудника',
#  'Контракт',
#  'Ставка (на текущую дату)',
#  'ЛПУ',
#  'Штатная должность (наименование)',
#  'Подразделение (наименование; им.падеж)',
#  'Подразделение (наименование)',
#  'Управленческий учет (Категория)',
#  'Состояние (мнемокод)',
#  'Табельный номер (без префикса)',
#  'Примечание',
#  'Вид контракта',
#  'Основное образование',
#  'Высшее образование',
#  'Дата рождения',
#  'Вид службы (работы)',
#  'Аттестация',
#  'Дополнительное соглашение',
#  'Дата  с (квалиф. катег.)',
#  'Дата заключения контракта',
#  'Дата окончания стажа',
#  'Дата (серт.)',
#  'Ученая степень сумма',
#  'Возраст',
#  'Оклад_НСОТ_ПО ШД',
#  'Вид работ',
#  'Выслуга лет',
#  'Вредность',
#  'За квалиф. уровень',
#  'Повышающий коэффициент',
#  'За квалиф. категорию',
#  'Вредность процент',
#  'Должностной оклад',
#  'Категория процент',
#  'Оклад_ЕТС',
#  'Праздничные',
#  '№сп из исп или из шт должн',
#  '№сп из исполнения',
#  '№сп из шт должн',
#  'Ставка без состояния(на текущую дату)',
#  'Стаж процент',
#  'Ученая процент',
#  'Признак подразделения',
#  'Управленческий учет (Подкатегория)',
#  'ОКТМО',
#  'Адрес (реального проживания)',
#  'Адрес (рождения)',
#  'Адрес(основной)',
#  'Адрес(юридический)',
#  'АО выборы',
#  'График работы',
#  'Доп тариф с исполнения',
#  'Доп. тариф солидарной части ПФР',
#  'ИНН',
#  'Истечение категории',
#  'ИФНС',
#  'Квал. категория',
#  'Контракт (вид)',
#  'Номер контракта',
#  'Пол',
#  'Проверка сертификата по..',
#  'Сертификат',
#  'СНИЛС',
#  'Соответствие категорий',
#  'СОУТ',
#  'Специальность (квал. катег.)',
#  'Специальность (серт.)',
#  'Наименование родительского подразделения',
#  'Подразделение',
#  'Дата начала работ по контракту',
#  'Дата прекращения контракта',
#  'Дата начала работ по дополнительному соглашению',
#  'Дата прекращения дополнительного соглашения',
#  'Категория получателя']

# %%
Staff7['Подразделение'].unique()
# Out:
# array(['Бухгалтерия', 'Инженерно-хозяйствен', 'ИАО', 'Исп.лаборатория',
#        'Консульт. отдел', 'Оперативный отдел', 'Организ.-метод.отдел',
#        'Отдел № 1', 'Отдел № 2', 'Отдел аттест.врач.ЛД', 'ОДК',
#        'Отдел закупок', 'ОИТ', 'Отдел кадров', 'ОКД и МФ', 'ОКЛД',
#        'Отдел маркетинга', 'ОРЛДЛД', 'ОРРТК', 'ОУСЛД',
#        'Отдел экспертизы и к', 'Отделение  № 1', 'РЦ отд.№1',
#        'Отделение  № 2', 'Отделение  № 3', 'Отделение  № 4',
#        'Отд. по работе с ОМС', 'ПЭО', 'ПАС', 'Проектный офис', 'РРО',
#        'Референс-центр', 'Секретариат', 'СКП', 'Сектор ОЗиИС',
#        'Сектор обучения и ра', 'Сектор реализации ск', 'УМО',
#        'Учебный центр', 'Центр по внедрению м'], dtype=object)

# %%
import pandas as pd
import openpyxl
Staff7= pd.read_excel('CopyШтат.xlsx')
val = Staff7['Отчество'].values[0]
val
# Out:
# 'Владимировна'

# %%
import pandas as pd
import openpyxl
Staff= pd.read_excel('CopyШтат.xlsx')
#Staff[['Фамилия', 'Имя',"Отчество","Табельный номер", "Должность", "Подразделение"]].head()
Staff[['Фамилия', 'Имя',"Отчество", "Подразделение"]][:30]
# Out:
#         Фамилия        Имя        Отчество         Подразделение
# 0    Панайотиди  Екатерина    Владимировна           Бухгалтерия
# 1     Толокнова        Ева   Александровна           Бухгалтерия
# 2     Клеенкова      Ольга    Владимировна           Бухгалтерия
# 3     Дарюшкина     Тамара      Михайловна  Инженерно-хозяйствен
# 4     Державина   Виктория   Станиславовна  Инженерно-хозяйствен
# 5     Мерзляков    Дмитрий       Андреевич  Инженерно-хозяйствен
# 6        Белкин    Дмитрий       Семенович  Инженерно-хозяйствен
# 7         Кузин     Сергей      Викторович  Инженерно-хозяйствен
# 8     Шаповалов       Олег       Андреевич  Инженерно-хозяйствен
# 9     Любарская    Наталья       Борисовна  Инженерно-хозяйствен
# 10     Нестеров   Анатолий      Викторович  Инженерно-хозяйствен
# 11    Журавлева      Алена      Алексеевна  Инженерно-хозяйствен
# 12      Бахарев    Дмитрий   Станиславович  Инженерно-хозяйствен
# 13       Лытаев   Владимир      Клавдиевич  Инженерно-хозяйствен
# 14      Расулов     Руслан  Хаджиаскарович  Инженерно-хозяйствен
# 15      Таранов   Владимир      Николаевич  Инженерно-хозяйствен
# 16    Журавлева    Надежда      Валерьевна  Инженерно-хозяйствен
# 17     Замятина     Марина      Викторовна  Инженерно-хозяйствен
# 18    Мухортова       Анна      Николаевна                   ИАО
# 19      Касымов     Парвиз       Эркинович                   ИАО
# 20        Филин     Михаил      Евгеньевич                   ИАО
# 21     Солдатов       Илья    Владимирович       Исп.лаборатория
# 22   Винниченко   Светлана       Сергеевна       Консульт. отдел
# 23  Мангурсузян      Минас      Рафаилович       Консульт. отдел
# 24     Любакова  Валентина      Викторовна     Оперативный отдел
# 25       Савчук    Валерия     Анатольевна     Оперативный отдел
# 26      Куликов     Андрей      Викторович     Оперативный отдел
# 27      Комкова       Алла    Владимировна     Оперативный отдел
# 28  Кривотулова      Ольга   Александровна     Оперативный отдел
# 29     Лазарева      Ирина    Владимировна     Оперативный отдел

# %%
import pandas as pd
import openpyxl as xl
#import numpy as np

Staff = pd.read_excel('CopyШтат.xlsx')                                                   # считываем файл со штатом сотрудников = Staff
TableForm = pd.read_excel('6.ФормаТабеля.xlsx', '0504421')          #добавляем файл, а именно табель сотрудика //то есть беру второй лист из трех






FullNameDep = (Staff["Фамилия"] + " " + Staff["Имя"] + " " + Staff["Отчество"] + " " + Staff["Табельный номер"] + " " + Staff["Подразделение"].astype("string")) # соединяем ФИО в единное целое //все люди из всех отделов 
FullName = (Staff["Фамилия"] + " " + Staff["Имя"] + " " + Staff["Отчество"] + " " + Staff["Подразделение"].astype("string"))
ColData = Staff['Подразделение'].unique()                                   # все виды УНИКАЛЬНЫХ отделов и т.п. взятые из колонки "V" "Подразделение"  файла 7.Штат.xlsx

for name in ColData:                                                                      # создание xlsx файлов с табелем сотрудника + названием должности из Staff, колонки Подразделение
    TableForm.to_excel(f'{name}.xlsx', index = False , header=False)  # убираем заголовки столбцов и нумерацию строк
    wb = xl.load_workbook(f'{name}.xlsx')                                             #загружаем 
    sheet = wb['Sheet1']                                                                            #присваеваем имя листу в xlsx файле
    sheet['B6'] = name                                                                               #закидываем имя файла = профессия = отдел etc в B6 //ячейка excel 
    wb.save(f'{name}.xlsx')                                                                       #сохраняем 
    
    
for name in ColData:
            if name = Staff["Подразделение"]:
                wb = xl.load_workbook(f'{name}.xlsx')    
                sheet['C14'] = FullName
                wb.save(f'{name}.xlsx')
# Out:
#   File "<ipython-input-7-3a3baa10e23e>", line 26
#     if name = Staff["Подразделение"]:
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import openpyxl as xl
Staff = pd.read_excel('CopyШтат.xlsx')   
TableForm = pd.read_excel('6.ФормаТабеля.xlsx', '0504421')


FullNameDep = (Staff["Surname"] + " " + Staff["Name"] + " " + Staff["patronymic"] + " " + Staff["Department"].astype("string")) 
FullName = (Staff["Surname"] + " " + Staff["Name"]  + " " + Staff["Department"].astype("string"))

ColData = Staff['Department'].unique()       


for name in ColData:     
    TableForm.to_excel(f'{name}.xlsx', index = False , header=False)
    wb = xl.load_workbook(f'{name}.xlsx')  
    sheet = wb['Sheet1']   
    sheet['B6'] = name    
    
for name in ColData:
    wb = xl.load_workbook(f'{name}.xlsx') 
    if wb{name} = Staff["Department"]:                   
                sheet['C14'] = FullName
    wb.save(f'{name}.xlsx')
# Out:
#   File "<ipython-input-18-ae80afd26a86>", line 21
#     if wb{name} = Staff["Department"]:
#          ^
# SyntaxError: invalid syntax
